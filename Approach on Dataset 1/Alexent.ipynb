# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
# Out:
# C:\Users\arnim\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\arnim\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
IMG_SIZE = (128, 128)
input_shape = IMG_SIZE + (3,)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.1
)

train_generator = train_datagen.flow_from_directory(
    'cropped',
    target_size=IMG_SIZE,
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    'cropped',
    target_size=IMG_SIZE,
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 5143 images belonging to 4 classes.
# Found 569 images belonging to 4 classes.

# %%
model = Sequential()
model.add(Conv2D(64, (11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(128, (5, 5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_generator.class_indices), activation='softmax'))
adam = Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 55, 55, 64)        23296
#
#  max_pooling2d_5 (MaxPoolin  (None, 27, 27, 64)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 27, 27, 128)       204928
#
#  max_pooling2d_6 (MaxPoolin  (None, 13, 13, 128)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 256)       295168
#
#  flatten_2 (Flatten)         (None, 43264)             0
#
#  dense_5 (Dense)             (None, 512)               22151680
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 22677124 (86.51 MB)
# Trainable params: 22677124 (86.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=30,
    steps_per_epoch=train_generator.samples // 32,
    validation_steps=validation_generator.samples // 32
)
loss, accuracy = model.evaluate(validation_generator)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()

plt.show()
# Out:
# Found 5143 images belonging to 4 classes.
# Found 569 images belonging to 4 classes.
# Epoch 1/30
# 160/160 [==============================] - 29s 175ms/step - loss: 1.0875 - accuracy: 0.5124 - val_loss: 0.9637 - val_accuracy: 0.6140
# Epoch 2/30
# 160/160 [==============================] - 26s 161ms/step - loss: 0.8170 - accuracy: 0.6693 - val_loss: 0.8169 - val_accuracy: 0.6783
# Epoch 3/30
# 160/160 [==============================] - 26s 162ms/step - loss: 0.7069 - accuracy: 0.7259 - val_loss: 0.9610 - val_accuracy: 0.5790
# Epoch 4/30
# 160/160 [==============================] - 26s 161ms/step - loss: 0.6515 - accuracy: 0.7488 - val_loss: 0.6836 - val_accuracy: 0.7298
# Epoch 5/30
# 160/160 [==============================] - 26s 161ms/step - loss: 0.5427 - accuracy: 0.7905 - val_loss: 0.7447 - val_accuracy: 0.7188
# Epoch 6/30
# 160/160 [==============================] - 26s 160ms/step - loss: 0.5002 - accuracy: 0.8083 - val_loss: 0.6176 - val_accuracy: 0.7684
# Epoch 7/30
# 160/160 [==============================] - 25s 158ms/step - loss: 0.4856 - accuracy: 0.8165 - val_loss: 0.6152 - val_accuracy: 0.7831
# Epoch 8/30
# 160/160 [==============================] - 25s 158ms/step - loss: 0.4284 - accuracy: 0.8419 - val_loss: 0.5910 - val_accuracy: 0.7886
# Epoch 9/30
# 160/160 [==============================] - 25s 158ms/step - loss: 0.4015 - accuracy: 0.8497 - val_loss: 0.5759 - val_accuracy: 0.7978
# Epoch 10/30
# 160/160 [==============================] - 25s 159ms/step - loss: 0.3544 - accuracy: 0.8675 - val_loss: 0.5464 - val_accuracy: 0.7831
# Epoch 11/30
# 160/160 [==============================] - 25s 159ms/step - loss: 0.3410 - accuracy: 0.8767 - val_loss: 0.5025 - val_accuracy: 0.7868
# Epoch 12/30
# 160/160 [==============================] - 27s 171ms/step - loss: 0.3226 - accuracy: 0.8848 - val_loss: 0.4917 - val_accuracy: 0.8235
# Epoch 13/30
# 160/160 [==============================] - 26s 161ms/step - loss: 0.3080 - accuracy: 0.8867 - val_loss: 0.5576 - val_accuracy: 0.8180
# Epoch 14/30
# 160/160 [==============================] - 26s 164ms/step - loss: 0.3270 - accuracy: 0.8820 - val_loss: 0.5182 - val_accuracy: 0.8051
# Epoch 15/30
# 160/160 [==============================] - 26s 164ms/step - loss: 0.2901 - accuracy: 0.8904 - val_loss: 0.7596 - val_accuracy: 0.7169
# Epoch 16/30
# 160/160 [==============================] - 26s 161ms/step - loss: 0.2720 - accuracy: 0.8967 - val_loss: 0.5492 - val_accuracy: 0.8070
# Epoch 17/30
# 160/160 [==============================] - 26s 162ms/step - loss: 0.2537 - accuracy: 0.9059 - val_loss: 0.5816 - val_accuracy: 0.7904
# Epoch 18/30
# 160/160 [==============================] - 26s 162ms/step - loss: 0.2623 - accuracy: 0.9006 - val_loss: 0.4834 - val_accuracy: 0.8529
# Epoch 19/30
# 160/160 [==============================] - 28s 177ms/step - loss: 0.2409 - accuracy: 0.9137 - val_loss: 0.3942 - val_accuracy: 0.8585
# Epoch 20/30
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2386 - accuracy: 0.9127 - val_loss: 0.3645 - val_accuracy: 0.8805
# Epoch 21/30
# 160/160 [==============================] - 26s 160ms/step - loss: 0.2276 - accuracy: 0.9127 - val_loss: 0.4904 - val_accuracy: 0.8364
# Epoch 22/30
# 160/160 [==============================] - 25s 157ms/step - loss: 0.2202 - accuracy: 0.9165 - val_loss: 0.4359 - val_accuracy: 0.8676
# Epoch 23/30
# 160/160 [==============================] - 25s 158ms/step - loss: 0.2096 - accuracy: 0.9235 - val_loss: 0.5094 - val_accuracy: 0.8143
# Epoch 24/30
# 160/160 [==============================] - 25s 157ms/step - loss: 0.2144 - accuracy: 0.9235 - val_loss: 0.4233 - val_accuracy: 0.8603
# Epoch 25/30
# 160/160 [==============================] - 25s 157ms/step - loss: 0.1888 - accuracy: 0.9315 - val_loss: 0.4594 - val_accuracy: 0.8676
# Epoch 26/30
# 160/160 [==============================] - 26s 163ms/step - loss: 0.1962 - accuracy: 0.9292 - val_loss: 0.5535 - val_accuracy: 0.7886
# Epoch 27/30
# 160/160 [==============================] - 25s 158ms/step - loss: 0.1959 - accuracy: 0.9286 - val_loss: 0.4668 - val_accuracy: 0.8621
# Epoch 28/30
# 160/160 [==============================] - 28s 173ms/step - loss: 0.1734 - accuracy: 0.9364 - val_loss: 0.3389 - val_accuracy: 0.9026
# Epoch 29/30
# 160/160 [==============================] - 27s 166ms/step - loss: 0.1721 - accuracy: 0.9362 - val_loss: 0.3541 - val_accuracy: 0.8842
# Epoch 30/30
# 160/160 [==============================] - 26s 165ms/step - loss: 0.1610 - accuracy: 0.9423 - val_loss: 0.5035 - val_accuracy: 0.8199
# 18/18 [==============================] - 2s 90ms/step - loss: 0.4704 - accuracy: 0.8418
# Validation Accuracy: 84.18%

# %%
# Save the model
model.save('brain_tumor_alexnet.h5')
# Out:
# C:\Users\arnim\anaconda3\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

IMG_SIZE = (227, 227)
input_shape = IMG_SIZE + (3,)
model = Sequential()
model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(256, (5, 5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_generator.class_indices), activation='softmax'))
adam = Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 55, 55, 96)        34944
#
#  max_pooling2d_2 (MaxPoolin  (None, 27, 27, 96)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 27, 27, 256)       614656
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 384)       885120
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 256)       884992
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 4096)              37752832
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 4096)              16781312
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 58297732 (222.39 MB)
# Trainable params: 58297732 (222.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(256, (5, 5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(384, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

# %%
adam = Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
